# %%
import numpy as np
import cupy as cp
import cuml
from cuml.decomposition import TruncatedSVD
from gensim.models import KeyedVectors
from scipy.stats import spearmanr
import csv
import pandas as pd
import gensim.downloader as api
import os

# %%
class ReducedEmbeddingModel:
    def __init__(self, vectors, index_to_key):
        self.vectors = vectors
        self.index_to_key = index_to_key
        self.key_to_index = {word: idx for idx, word in enumerate(index_to_key)}
    
    def __getitem__(self, word):
        if word in self.key_to_index:
            return self.vectors[self.key_to_index[word]]
        raise KeyError(f"Word '{word}' not found in vocabulary")
    
    def __contains__(self, word):
        return word in self.key_to_index

def load_word2vec_model(file_path):
    """Loads Word2Vec embeddings from a binary file."""
    print("Loading Word2Vec model...")
    wv = KeyedVectors.load_word2vec_format(file_path, binary=True)
    vectors = wv.vectors
    index_to_key = wv.index_to_key
    return ReducedEmbeddingModel(vectors, index_to_key)
    
# Load SimLex-999 word similarity data
def load_simlex_999(file_path):
    """Loads SimLex-999 and returns word pairs with similarity scores."""
    data = []
    with open(file_path, 'r') as file:
        next(file)  # Skip header
        for line in file:
            parts = line.strip().split('\t')
            word1, word2, similarity_score = parts[0], parts[1], float(parts[3])
            data.append((word1, word2, similarity_score))
    return data

# Cosine similarity function for similarity evaluation
def cosine_similarity(v1, v2):
    norm1 = np.linalg.norm(v1)
    norm2 = np.linalg.norm(v2)
    if norm1 == 0 or norm2 == 0:
        return 0
    return np.dot(v1, v2) / (norm1 * norm2)

# Evaluate embeddings on the word similarity data
def evaluate_embeddings(model, word_pairs):
    predicted_scores = []
    true_scores = []
    
    for word1, word2, true_score in word_pairs:
        if word1 in model and word2 in model:
            sim_score = cosine_similarity(model[word1], model[word2])
            predicted_scores.append(sim_score)
            true_scores.append(true_score)
    
    # Calculate Spearman correlation for word similarity performance
    correlation, _ = spearmanr(true_scores, predicted_scores)
    return correlation

# Task-driven dimensionality reduction using cuML's PCA with optimization for similarity
def task_driven_dimensionality_reduction(embeddings, target_dim=2, word_pairs=None, model=None):
    """Reduces dimensions while optimizing for similarity correlation and visualizes component removal impact."""
    
    # Convert numpy array to CuPy array for GPU processing
    cu_embeddings = cp.asarray(embeddings)
    
    # Initialize cuML PCA for dimensionality reduction
    # pca = cumlPCA(n_components=target_dim)
    svd = TruncatedSVD(n_components=target_dim, algorithm="full")
    reduced_embeddings = svd.fit_transform(cu_embeddings)
    
    # Convert back to numpy for further processing
    reduced_embeddings = cp.asnumpy(reduced_embeddings)
    
    # Create a reduced model to store optimized embeddings
    optimized_model = {word: reduced_embeddings[i] for i, word in enumerate(model.index_to_key)}
    
    # Evaluate initial PCA reduction
    initial_correlation = evaluate_embeddings(optimized_model, word_pairs)
    print(f"Initial Spearman Correlation after PCA to {target_dim}D: {initial_correlation:.4f}")
    
    # Initialize variables for tracking
    best_correlation = initial_correlation
    best_embeddings = reduced_embeddings
    correlations = [initial_correlation]  # Track correlations for each component removal count
    components_removed = [0]  # Track the number of components removed

    # Fine-tune PCA by adjusting top components
    for top_n in range(0, 299, 1):  # Try removing 0 to 298 top components
        # Re-apply PCA with additional top components
        svd_adjusted = TruncatedSVD(n_components=target_dim + top_n)
        expanded_embeddings = svd_adjusted.fit_transform(cu_embeddings)
        
        # Convert back to numpy
        expanded_embeddings = cp.asnumpy(expanded_embeddings)
        
        # Remove top components by zeroing them out to retain task-specific dimensions
        adjusted_embeddings = expanded_embeddings[:, top_n:]
        
        # Update the model with new adjusted embeddings
        adjusted_model = {word: adjusted_embeddings[i] for i, word in enumerate(model.index_to_key)}
        
        # Evaluate correlation on SimLex-999
        correlation = evaluate_embeddings(adjusted_model, word_pairs)
        print(f"Adjusted Correlation after removing top {top_n} components: {correlation:.4f}")
        
        # Append data for plotting
        correlations.append(correlation)
        components_removed.append(top_n)
        
        # Track the best adjustment that maximizes the Spearman correlation
        if correlation > best_correlation:
            best_correlation = correlation
            best_embeddings = adjusted_embeddings
    
    print(f"Best Spearman Correlation with Task-Driven Reduction: {best_correlation:.4f}")
    
    return best_embeddings, best_correlation

# %%
word2vec_file_path = '/teamspace/uploads/GoogleNews-vectors-negative300.bin'  # Path to your Word2Vec binary file
simlex_file_path = '/teamspace/studios/pca/SimLex-999.txt'  # Update this path to your SimLex-999 file
target_dim = 2  # Adjust target_dim as needed for testing (e.g., 150, 100, 50)

# Load Word2Vec model
original_model = load_word2vec_model(word2vec_file_path)

# Load word similarity dataset
word_pairs = load_simlex_999(simlex_file_path)
# Out:
# Loading Word2Vec model...

# %%
# Perform task-driven dimensionality reduction
optimized_embeddings, best_correlation = task_driven_dimensionality_reduction(
    original_model.vectors, 
    target_dim=target_dim, 
    word_pairs=word_pairs, 
    model=original_model
)

print(f"\nFinal Optimized Spearman Correlation at {target_dim}D: {best_correlation:.4f}")
# Out:
# Initial Spearman Correlation after PCA to 2D: 0.0170
# Adjusted Correlation after removing top 0 components: 0.0170
# Adjusted Correlation after removing top 1 components: -0.0408
# Adjusted Correlation after removing top 2 components: -0.0221
# Adjusted Correlation after removing top 3 components: -0.0058
# Adjusted Correlation after removing top 4 components: 0.0352
# Adjusted Correlation after removing top 5 components: 0.1152
# Adjusted Correlation after removing top 6 components: 0.1127
# Adjusted Correlation after removing top 7 components: 0.0896
# Adjusted Correlation after removing top 8 components: 0.0715
# Adjusted Correlation after removing top 9 components: 0.1217
# Adjusted Correlation after removing top 10 components: 0.1386
# Adjusted Correlation after removing top 11 components: 0.1199
# Adjusted Correlation after removing top 12 components: 0.0724
# Adjusted Correlation after removing top 13 components: 0.0524
# Adjusted Correlation after removing top 14 components: 0.0973
# Adjusted Correlation after removing top 15 components: 0.0290
# Adjusted Correlation after removing top 16 components: 0.0228
# Adjusted Correlation after removing top 17 components: 0.0159
# Adjusted Correlation after removing top 18 components: 0.0585
# Adjusted Correlation after removing top 19 components: 0.1015
# Adjusted Correlation after removing top 20 components: 0.1036
# Adjusted Correlation after removing top 21 components: 0.1047
# Adjusted Correlation after removing top 22 components: 0.1236
# Adjusted Correlation after removing top 23 components: 0.1237
# Adjusted Correlation after removing top 24 components: 0.1234
# Adjusted Correlation after removing top 25 components: 0.1184
# Adjusted Correlation after removing top 26 components: 0.0795
# Adjusted Correlation after removing top 27 components: 0.0537
# Adjusted Correlation after removing top 28 components: 0.0512
# Adjusted Correlation after removing top 29 components: 0.0638
# Adjusted Correlation after removing top 30 components: 0.0690
# Adjusted Correlation after removing top 31 components: 0.0716
# Adjusted Correlation after removing top 32 components: 0.0713
# Adjusted Correlation after removing top 33 components: 0.0475
# Adjusted Correlation after removing top 34 components: 0.0860
# Adjusted Correlation after removing top 35 components: 0.1054
# Adjusted Correlation after removing top 36 components: 0.0823
# Adjusted Correlation after removing top 37 components: 0.0719
# Adjusted Correlation after removing top 38 components: 0.0720
# Adjusted Correlation after removing top 39 components: 0.0623
# Adjusted Correlation after removing top 40 components: 0.1367
# Adjusted Correlation after removing top 41 components: 0.0809
# Adjusted Correlation after removing top 42 components: 0.0966
# Adjusted Correlation after removing top 43 components: 0.0908
# Adjusted Correlation after removing top 44 components: 0.0580
# Adjusted Correlation after removing top 45 components: 0.1182
# Adjusted Correlation after removing top 46 components: 0.1598
# Adjusted Correlation after removing top 47 components: 0.1746
# Adjusted Correlation after removing top 48 components: 0.1590
# Adjusted Correlation after removing top 49 components: 0.1146
# Adjusted Correlation after removing top 50 components: 0.1219
# Adjusted Correlation after removing top 51 components: 0.1089
# Adjusted Correlation after removing top 52 components: 0.0986
# Adjusted Correlation after removing top 53 components: 0.1092
# Adjusted Correlation after removing top 54 components: 0.1238
# Adjusted Correlation after removing top 55 components: 0.1071
# Adjusted Correlation after removing top 56 components: 0.0315
# Adjusted Correlation after removing top 57 components: 0.0638
# Adjusted Correlation after removing top 58 components: 0.1111
# Adjusted Correlation after removing top 59 components: 0.1378
# Adjusted Correlation after removing top 60 components: 0.0941
# Adjusted Correlation after removing top 61 components: 0.0995
# Adjusted Correlation after removing top 62 components: 0.0157
# Adjusted Correlation after removing top 63 components: -0.0202
# Adjusted Correlation after removing top 64 components: 0.0979
# Adjusted Correlation after removing top 65 components: 0.1897
# Adjusted Correlation after removing top 66 components: 0.1526
# Adjusted Correlation after removing top 67 components: 0.1391
# Adjusted Correlation after removing top 68 components: 0.1315
# Adjusted Correlation after removing top 69 components: 0.1634
# Adjusted Correlation after removing top 70 components: 0.1098
# Adjusted Correlation after removing top 71 components: 0.0986
# Adjusted Correlation after removing top 72 components: 0.1052
# Adjusted Correlation after removing top 73 components: 0.1358
# Adjusted Correlation after removing top 74 components: 0.1453
# Adjusted Correlation after removing top 75 components: 0.1245
# Adjusted Correlation after removing top 76 components: 0.1191
# Adjusted Correlation after removing top 77 components: 0.1323
# Adjusted Correlation after removing top 78 components: 0.1213
# Adjusted Correlation after removing top 79 components: 0.0622
# Adjusted Correlation after removing top 80 components: 0.0745
# Adjusted Correlation after removing top 81 components: 0.1586
# Adjusted Correlation after removing top 82 components: 0.1494
# Adjusted Correlation after removing top 83 components: 0.0753
# Adjusted Correlation after removing top 84 components: 0.0702
# Adjusted Correlation after removing top 85 components: 0.0571
# Adjusted Correlation after removing top 86 components: 0.1061
# Adjusted Correlation after removing top 87 components: 0.0739
# Adjusted Correlation after removing top 88 components: 0.1004
# Adjusted Correlation after removing top 89 components: 0.0743
# Adjusted Correlation after removing top 90 components: 0.0964
# Adjusted Correlation after removing top 91 components: 0.0741
# Adjusted Correlation after removing top 92 components: 0.0674
# Adjusted Correlation after removing top 93 components: 0.1209
# Adjusted Correlation after removing top 94 components: 0.1604
# Adjusted Correlation after removing top 95 components: 0.1461
# Adjusted Correlation after removing top 96 components: 0.0860
# Adjusted Correlation after removing top 97 components: 0.0898
# Adjusted Correlation after removing top 98 components: 0.0513
# Adjusted Correlation after removing top 99 components: 0.0275
# Adjusted Correlation after removing top 100 components: 0.0673
# Adjusted Correlation after removing top 101 components: 0.1663
# Adjusted Correlation after removing top 102 components: 0.1461
# Adjusted Correlation after removing top 103 components: 0.1202
# Adjusted Correlation after removing top 104 components: 0.1157
# Adjusted Correlation after removing top 105 components: 0.1385
# Adjusted Correlation after removing top 106 components: 0.0789
# Adjusted Correlation after removing top 107 components: 0.0999
# Adjusted Correlation after removing top 108 components: 0.0638
# Adjusted Correlation after removing top 109 components: 0.0547
# Adjusted Correlation after removing top 110 components: 0.1432
# Adjusted Correlation after removing top 111 components: 0.1817
# Adjusted Correlation after removing top 112 components: 0.1624
# Adjusted Correlation after removing top 113 components: 0.1452
# Adjusted Correlation after removing top 114 components: 0.2111
# Adjusted Correlation after removing top 115 components: 0.1906
# Adjusted Correlation after removing top 116 components: 0.1422
# Adjusted Correlation after removing top 117 components: 0.1382
# Adjusted Correlation after removing top 118 components: 0.1446
# Adjusted Correlation after removing top 119 components: 0.0744
# Adjusted Correlation after removing top 120 components: 0.0341
# Adjusted Correlation after removing top 121 components: 0.0401
# Adjusted Correlation after removing top 122 components: 0.1356
# Adjusted Correlation after removing top 123 components: 0.1268
# Adjusted Correlation after removing top 124 components: 0.0999
# Adjusted Correlation after removing top 125 components: 0.1261
# Adjusted Correlation after removing top 126 components: 0.1425
# Adjusted Correlation after removing top 127 components: 0.1276
# Adjusted Correlation after removing top 128 components: 0.1388
# Adjusted Correlation after removing top 129 components: 0.0927
# Adjusted Correlation after removing top 130 components: 0.0882
# Adjusted Correlation after removing top 131 components: 0.1551
# Adjusted Correlation after removing top 132 components: 0.1139
# Adjusted Correlation after removing top 133 components: 0.0582
# Adjusted Correlation after removing top 134 components: 0.0969
# Adjusted Correlation after removing top 135 components: 0.1370
# Adjusted Correlation after removing top 136 components: 0.0626
# Adjusted Correlation after removing top 137 components: 0.0864
# Adjusted Correlation after removing top 138 components: 0.1241
# Adjusted Correlation after removing top 139 components: 0.1504
# Adjusted Correlation after removing top 140 components: 0.1272
# Adjusted Correlation after removing top 141 components: 0.1295
# Adjusted Correlation after removing top 142 components: 0.1028
# Adjusted Correlation after removing top 143 components: 0.0560
# Adjusted Correlation after removing top 144 components: 0.1144
# Adjusted Correlation after removing top 145 components: 0.0950
# Adjusted Correlation after removing top 146 components: 0.0259
# Adjusted Correlation after removing top 147 components: 0.0719
# Adjusted Correlation after removing top 148 components: 0.0771
# Adjusted Correlation after removing top 149 components: 0.1135
# Adjusted Correlation after removing top 150 components: 0.0850
# Adjusted Correlation after removing top 151 components: 0.1045
# Adjusted Correlation after removing top 152 components: 0.1554
# Adjusted Correlation after removing top 153 components: 0.1366
# Adjusted Correlation after removing top 154 components: 0.1091
# Adjusted Correlation after removing top 155 components: 0.1107
# Adjusted Correlation after removing top 156 components: 0.1256
# Adjusted Correlation after removing top 157 components: 0.1213
# Adjusted Correlation after removing top 158 components: 0.0972
# Adjusted Correlation after removing top 159 components: 0.0813
# Adjusted Correlation after removing top 160 components: 0.1299
# Adjusted Correlation after removing top 161 components: 0.1251
# Adjusted Correlation after removing top 162 components: 0.1343
# Adjusted Correlation after removing top 163 components: 0.1697
# Adjusted Correlation after removing top 164 components: 0.1146
# Adjusted Correlation after removing top 165 components: 0.0914
# Adjusted Correlation after removing top 166 components: 0.1057
# Adjusted Correlation after removing top 167 components: 0.0769
# Adjusted Correlation after removing top 168 components: 0.1147
# Adjusted Correlation after removing top 169 components: 0.0825
# Adjusted Correlation after removing top 170 components: 0.0124
# Adjusted Correlation after removing top 171 components: 0.0939
# Adjusted Correlation after removing top 172 components: 0.1953
# Adjusted Correlation after removing top 173 components: 0.1298
# Adjusted Correlation after removing top 174 components: 0.1035
# Adjusted Correlation after removing top 175 components: 0.1033
# Adjusted Correlation after removing top 176 components: 0.0508
# Adjusted Correlation after removing top 177 components: 0.0636
# Adjusted Correlation after removing top 178 components: 0.1369
# Adjusted Correlation after removing top 179 components: 0.1044
# Adjusted Correlation after removing top 180 components: 0.0819
# Adjusted Correlation after removing top 181 components: 0.0753
# Adjusted Correlation after removing top 182 components: 0.1179
# Adjusted Correlation after removing top 183 components: 0.1284
# Adjusted Correlation after removing top 184 components: 0.1370
# Adjusted Correlation after removing top 185 components: 0.1415
# Adjusted Correlation after removing top 186 components: 0.1003
# Adjusted Correlation after removing top 187 components: 0.1056
# Adjusted Correlation after removing top 188 components: 0.1192
# Adjusted Correlation after removing top 189 components: 0.1036
# Adjusted Correlation after removing top 190 components: 0.1194
# Adjusted Correlation after removing top 191 components: 0.0788
# Adjusted Correlation after removing top 192 components: -0.0063
# Adjusted Correlation after removing top 193 components: 0.0760
# Adjusted Correlation after removing top 194 components: 0.1390
# Adjusted Correlation after removing top 195 components: 0.1325
# Adjusted Correlation after removing top 196 components: 0.1612
# Adjusted Correlation after removing top 197 components: 0.1433
# Adjusted Correlation after removing top 198 components: 0.1201
# Adjusted Correlation after removing top 199 components: 0.1059
# Adjusted Correlation after removing top 200 components: 0.1264
# Adjusted Correlation after removing top 201 components: 0.1014
# Adjusted Correlation after removing top 202 components: 0.1189
# Adjusted Correlation after removing top 203 components: 0.1298
# Adjusted Correlation after removing top 204 components: 0.1457
# Adjusted Correlation after removing top 205 components: 0.1835
# Adjusted Correlation after removing top 206 components: 0.1122
# Adjusted Correlation after removing top 207 components: 0.0944
# Adjusted Correlation after removing top 208 components: 0.1378
# Adjusted Correlation after removing top 209 components: 0.0866
# Adjusted Correlation after removing top 210 components: 0.0874
# Adjusted Correlation after removing top 211 components: 0.1319
# Adjusted Correlation after removing top 212 components: 0.0958
# Adjusted Correlation after removing top 213 components: 0.0914
# Adjusted Correlation after removing top 214 components: 0.0744
# Adjusted Correlation after removing top 215 components: 0.1111
# Adjusted Correlation after removing top 216 components: 0.1168
# Adjusted Correlation after removing top 217 components: 0.1238
# Adjusted Correlation after removing top 218 components: 0.1538
# Adjusted Correlation after removing top 219 components: 0.1169
# Adjusted Correlation after removing top 220 components: 0.1118
# Adjusted Correlation after removing top 221 components: 0.1590
# Adjusted Correlation after removing top 222 components: 0.1470
# Adjusted Correlation after removing top 223 components: 0.1400
# Adjusted Correlation after removing top 224 components: 0.1093
# Adjusted Correlation after removing top 225 components: 0.0825
# Adjusted Correlation after removing top 226 components: 0.1040
# Adjusted Correlation after removing top 227 components: 0.0663
# Adjusted Correlation after removing top 228 components: 0.0659
# Adjusted Correlation after removing top 229 components: 0.1515
# Adjusted Correlation after removing top 230 components: 0.0892
# Adjusted Correlation after removing top 231 components: 0.0745
# Adjusted Correlation after removing top 232 components: 0.0999
# Adjusted Correlation after removing top 233 components: 0.1442
# Adjusted Correlation after removing top 234 components: 0.1590
# Adjusted Correlation after removing top 235 components: 0.1127
# Adjusted Correlation after removing top 236 components: 0.0771
# Adjusted Correlation after removing top 237 components: 0.1014
# Adjusted Correlation after removing top 238 components: 0.0726
# Adjusted Correlation after removing top 239 components: 0.0671
# Adjusted Correlation after removing top 240 components: 0.0724
# Adjusted Correlation after removing top 241 components: 0.0816
# Adjusted Correlation after removing top 242 components: 0.0932
# Adjusted Correlation after removing top 243 components: 0.1467
# Adjusted Correlation after removing top 244 components: 0.1032
# Adjusted Correlation after removing top 245 components: 0.0500
# Adjusted Correlation after removing top 246 components: 0.0529
# Adjusted Correlation after removing top 247 components: 0.1382
# Adjusted Correlation after removing top 248 components: 0.1613
# Adjusted Correlation after removing top 249 components: 0.1307
# Adjusted Correlation after removing top 250 components: 0.0952
# Adjusted Correlation after removing top 251 components: 0.1384
# Adjusted Correlation after removing top 252 components: 0.1203
# Adjusted Correlation after removing top 253 components: 0.0823
# Adjusted Correlation after removing top 254 components: 0.0904
# Adjusted Correlation after removing top 255 components: 0.1022
# Adjusted Correlation after removing top 256 components: 0.1193
# Adjusted Correlation after removing top 257 components: 0.1284
# Adjusted Correlation after removing top 258 components: 0.0996
# Adjusted Correlation after removing top 259 components: 0.1251
# Adjusted Correlation after removing top 260 components: 0.1507
# Adjusted Correlation after removing top 261 components: 0.0835
# Adjusted Correlation after removing top 262 components: 0.1026
# Adjusted Correlation after removing top 263 components: 0.1302
# Adjusted Correlation after removing top 264 components: 0.1170
# Adjusted Correlation after removing top 265 components: 0.1127
# Adjusted Correlation after removing top 266 components: 0.1288
# Adjusted Correlation after removing top 267 components: 0.0852
# Adjusted Correlation after removing top 268 components: 0.0884
# Adjusted Correlation after removing top 269 components: 0.1457
# Adjusted Correlation after removing top 270 components: 0.1441
# Adjusted Correlation after removing top 271 components: 0.0848
# Adjusted Correlation after removing top 272 components: 0.1365
# Adjusted Correlation after removing top 273 components: 0.1611
# Adjusted Correlation after removing top 274 components: 0.1357
# Adjusted Correlation after removing top 275 components: 0.1304
# Adjusted Correlation after removing top 276 components: 0.1302
# Adjusted Correlation after removing top 277 components: 0.1237
# Adjusted Correlation after removing top 278 components: 0.1460
# Adjusted Correlation after removing top 279 components: 0.1775
# Adjusted Correlation after removing top 280 components: 0.1392
# Adjusted Correlation after removing top 281 components: 0.1508
# Adjusted Correlation after removing top 282 components: 0.1458
# Adjusted Correlation after removing top 283 components: 0.1253
# Adjusted Correlation after removing top 284 components: 0.1294
# Adjusted Correlation after removing top 285 components: 0.1005
# Adjusted Correlation after removing top 286 components: 0.1437
# Adjusted Correlation after removing top 287 components: 0.1256
# Adjusted Correlation after removing top 288 components: 0.1400
# Adjusted Correlation after removing top 289 components: 0.0958
# Adjusted Correlation after removing top 290 components: 0.1111
# Adjusted Correlation after removing top 291 components: 0.1652
# Adjusted Correlation after removing top 292 components: 0.1483
# Adjusted Correlation after removing top 293 components: 0.0805
# Adjusted Correlation after removing top 294 components: 0.1027
# Adjusted Correlation after removing top 295 components: 0.1054
# Adjusted Correlation after removing top 296 components: 0.1007
# Adjusted Correlation after removing top 297 components: 0.1085
# Adjusted Correlation after removing top 298 components: 0.1259
# Best Spearman Correlation with Task-Driven Reduction: 0.2111
#
# Final Optimized Spearman Correlation at 2D: 0.2111

# %%
# Save the 2D embeddings with word labels to a CSV file
def save_embeddings_to_csv(words, embeddings, file_path):
    print(f"Saving 2D embeddings to {file_path}...")
    df = pd.DataFrame(embeddings, columns=['x', 'y'])
    df['word'] = words
    df.to_csv(file_path, index=False)
    print("2D embeddings saved successfully.")

# %%
# Get words and their high-dimensional embeddings
words = original_model.index_to_key  # List of words in vocabulary
file_path="TruncatedSVD_Word2Vec_2d_word_embeddings.csv"
# Save the embeddings and words to a CSV file
save_embeddings_to_csv(words, optimized_embeddings, file_path)
# Out:
# Saving 2D embeddings to TruncatedSVD_Word2Vec_2d_word_embeddings.csv...
# 2D embeddings saved successfully.

# %%
import matplotlib.pyplot as plt
import re

def extract_and_plot_data(filepath):
    """
    Extracts data from a text file, groups it, calculates averages, and plots the results.

    Args:
        filepath: The path to the text file.
    """

    correlations = []
    with open(filepath, 'r') as f:
        for line in f:
            match = re.search(r"Adjusted Correlation after removing top (\d+) components: (-?\d+\.\d+)", line)
            if match:
                num_components = int(match.group(1))
                correlation = float(match.group(2))
                correlations.append((num_components, correlation))

    # Group data and calculate averages
    group_averages = []
    group_labels = []
    for i in range(0, 300, 30):  # Changed step size from 50 to 30
        group = [corr for comp, corr in correlations if i <= comp < i + 30]  # Changed range from 50 to 30
        if group:  # Check if the group is not empty
            average_correlation = sum(group) / len(group)
            group_averages.append(average_correlation)
            group_labels.append(f"{i}-{min(i + 29, 299)}")  # Changed from i + 49 to i + 29

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(group_labels, group_averages, marker='o', linestyle='-')
    plt.xlabel("Number of Components Removed (Groups)")
    plt.ylabel("Average Adjusted Correlation")
    plt.title("Average Adjusted Correlation vs. Number of Components Removed")
    plt.grid(True)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()
    plt.show()

# Example usage:
filepath = '/teamspace/studios/this_studio/TRUNCATED SVD/TruncatedSVD_Word2Vec_data.txt'  # Replace with your file path
extract_and_plot_data(filepath)
