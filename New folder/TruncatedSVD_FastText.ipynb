# %%
import numpy as np
import cupy as cp
import cuml
from cuml.decomposition import TruncatedSVD
from gensim.models import KeyedVectors
from scipy.stats import spearmanr
import csv
import pandas as pd
import gensim.downloader as api
import os

# %%
# Load the pre-trained FastText model
def load_fasttext_model():
    os.environ["GENSIM_DATA_DIR"] = "/teamspace/studios/pca/gensim-data"
    fasttext_model = api.load('fasttext-wiki-news-subwords-300')
    return fasttext_model
    
# Load SimLex-999 word similarity data
def load_simlex_999(file_path):
    """Loads SimLex-999 and returns word pairs with similarity scores."""
    data = []
    with open(file_path, 'r') as file:
        next(file)  # Skip header
        for line in file:
            parts = line.strip().split('\t')
            word1, word2, similarity_score = parts[0], parts[1], float(parts[3])
            data.append((word1, word2, similarity_score))
    return data

# Cosine similarity function for similarity evaluation
def cosine_similarity(v1, v2):
    norm1 = np.linalg.norm(v1)
    norm2 = np.linalg.norm(v2)
    if norm1 == 0 or norm2 == 0:
        return 0
    return np.dot(v1, v2) / (norm1 * norm2)

# Evaluate embeddings on the word similarity data
def evaluate_embeddings(model, word_pairs):
    predicted_scores = []
    true_scores = []
    
    for word1, word2, true_score in word_pairs:
        if word1 in model and word2 in model:
            sim_score = cosine_similarity(model[word1], model[word2])
            predicted_scores.append(sim_score)
            true_scores.append(true_score)
    
    # Calculate Spearman correlation for word similarity performance
    correlation, _ = spearmanr(true_scores, predicted_scores)
    return correlation

# Task-driven dimensionality reduction using cuML's PCA with optimization for similarity
def task_driven_dimensionality_reduction(embeddings, target_dim=2, word_pairs=None, model=None):
    """Reduces dimensions while optimizing for similarity correlation and visualizes component removal impact."""
    
    # Convert numpy array to CuPy array for GPU processing
    cu_embeddings = cp.asarray(embeddings)
    
    # Initialize cuML PCA for dimensionality reduction
    # pca = cumlPCA(n_components=target_dim)
    svd = TruncatedSVD(n_components=target_dim, algorithm="full")
    reduced_embeddings = svd.fit_transform(cu_embeddings)
    
    # Convert back to numpy for further processing
    reduced_embeddings = cp.asnumpy(reduced_embeddings)
    
    # Create a reduced model to store optimized embeddings
    optimized_model = {word: reduced_embeddings[i] for i, word in enumerate(model.index_to_key)}
    
    # Evaluate initial Truncated SVD reduction
    initial_correlation = evaluate_embeddings(optimized_model, word_pairs)
    print(f"Initial Spearman Correlation after truncated svd to {target_dim}D: {initial_correlation:.4f}")
    
    # Initialize variables for tracking
    best_correlation = initial_correlation
    best_embeddings = reduced_embeddings
    correlations = [initial_correlation]  # Track correlations for each component removal count
    components_removed = [0]  # Track the number of components removed

    # Fine-tune  by adjusting top components
    for top_n in range(0, 299, 1):  # Try removing 0 to 298 top components
        # Re-apply PCA with additional top components
        svd_adjusted = TruncatedSVD(n_components=target_dim + top_n)
        expanded_embeddings = svd_adjusted.fit_transform(cu_embeddings)
        
        # Convert back to numpy
        expanded_embeddings = cp.asnumpy(expanded_embeddings)
        
        # Remove top components by zeroing them out to retain task-specific dimensions
        adjusted_embeddings = expanded_embeddings[:, top_n:]
        
        # Update the model with new adjusted embeddings
        adjusted_model = {word: adjusted_embeddings[i] for i, word in enumerate(model.index_to_key)}
        
        # Evaluate correlation on SimLex-999
        correlation = evaluate_embeddings(adjusted_model, word_pairs)
        print(f"Adjusted Correlation after removing top {top_n} components: {correlation:.4f}")
        
        # Append data for plotting
        correlations.append(correlation)
        components_removed.append(top_n)
        
        # Track the best adjustment that maximizes the Spearman correlation
        if correlation > best_correlation:
            best_correlation = correlation
            best_embeddings = adjusted_embeddings
    
    print(f"Best Spearman Correlation with Task-Driven Reduction: {best_correlation:.4f}")
    
    return best_embeddings, best_correlation

# %%
simlex_file_path = '/teamspace/studios/pca/SimLex-999.txt'  # Update this path to your SimLex-999 file
target_dim = 2  # Adjust target_dim as needed for testing (e.g., 150, 100, 50)

# %%
print("Loading FastText model...")
original_model = load_fasttext_model()
# Out:
# Loading FastText model...

# %%
word_pairs = load_simlex_999(simlex_file_path)

# %%
# Perform task-driven dimensionality reduction
optimized_embeddings, best_correlation = task_driven_dimensionality_reduction(
    original_model.vectors, 
    target_dim=target_dim, 
    word_pairs=word_pairs, 
    model=original_model
)

print(f"\nFinal Optimized Spearman Correlation at {target_dim}D: {best_correlation:.4f}")
# Out:
# Initial Spearman Correlation after PCA to 2D: 0.0844
# Adjusted Correlation after removing top 0 components: 0.0844
# Adjusted Correlation after removing top 1 components: 0.0644
# Adjusted Correlation after removing top 2 components: 0.0487
# Adjusted Correlation after removing top 3 components: 0.0486
# Adjusted Correlation after removing top 4 components: 0.0639
# Adjusted Correlation after removing top 5 components: 0.1008
# Adjusted Correlation after removing top 6 components: 0.1598
# Adjusted Correlation after removing top 7 components: 0.1745
# Adjusted Correlation after removing top 8 components: 0.1512
# Adjusted Correlation after removing top 9 components: 0.1470
# Adjusted Correlation after removing top 10 components: 0.0874
# Adjusted Correlation after removing top 11 components: 0.0502
# Adjusted Correlation after removing top 12 components: 0.0657
# Adjusted Correlation after removing top 13 components: 0.0376
# Adjusted Correlation after removing top 14 components: 0.0339
# Adjusted Correlation after removing top 15 components: 0.0516
# Adjusted Correlation after removing top 16 components: 0.1359
# Adjusted Correlation after removing top 17 components: 0.1371
# Adjusted Correlation after removing top 18 components: 0.1248
# Adjusted Correlation after removing top 19 components: 0.1588
# Adjusted Correlation after removing top 20 components: 0.1492
# Adjusted Correlation after removing top 21 components: 0.1444
# Adjusted Correlation after removing top 22 components: 0.1409
# Adjusted Correlation after removing top 23 components: 0.1130
# Adjusted Correlation after removing top 24 components: 0.1370
# Adjusted Correlation after removing top 25 components: 0.0653
# Adjusted Correlation after removing top 26 components: 0.0941
# Adjusted Correlation after removing top 27 components: 0.0987
# Adjusted Correlation after removing top 28 components: 0.1142
# Adjusted Correlation after removing top 29 components: 0.1149
# Adjusted Correlation after removing top 30 components: 0.1164
# Adjusted Correlation after removing top 31 components: 0.1114
# Adjusted Correlation after removing top 32 components: 0.1673
# Adjusted Correlation after removing top 33 components: 0.1577
# Adjusted Correlation after removing top 34 components: 0.1169
# Adjusted Correlation after removing top 35 components: 0.0785
# Adjusted Correlation after removing top 36 components: 0.1129
# Adjusted Correlation after removing top 37 components: 0.1432
# Adjusted Correlation after removing top 38 components: 0.0257
# Adjusted Correlation after removing top 39 components: 0.1252
# Adjusted Correlation after removing top 40 components: 0.2046
# Adjusted Correlation after removing top 41 components: 0.1394
# Adjusted Correlation after removing top 42 components: 0.0972
# Adjusted Correlation after removing top 43 components: 0.0908
# Adjusted Correlation after removing top 44 components: 0.0388
# Adjusted Correlation after removing top 45 components: 0.0864
# Adjusted Correlation after removing top 46 components: 0.2073
# Adjusted Correlation after removing top 47 components: 0.1552
# Adjusted Correlation after removing top 48 components: 0.1691
# Adjusted Correlation after removing top 49 components: 0.1521
# Adjusted Correlation after removing top 50 components: 0.1482
# Adjusted Correlation after removing top 51 components: 0.1188
# Adjusted Correlation after removing top 52 components: 0.1260
# Adjusted Correlation after removing top 53 components: 0.0713
# Adjusted Correlation after removing top 54 components: 0.1323
# Adjusted Correlation after removing top 55 components: 0.1186
# Adjusted Correlation after removing top 56 components: 0.0821
# Adjusted Correlation after removing top 57 components: 0.0717
# Adjusted Correlation after removing top 58 components: 0.0950
# Adjusted Correlation after removing top 59 components: 0.1386
# Adjusted Correlation after removing top 60 components: 0.1755
# Adjusted Correlation after removing top 61 components: 0.0801
# Adjusted Correlation after removing top 62 components: 0.0697
# Adjusted Correlation after removing top 63 components: 0.1548
# Adjusted Correlation after removing top 64 components: 0.1241
# Adjusted Correlation after removing top 65 components: 0.0794
# Adjusted Correlation after removing top 66 components: 0.0661
# Adjusted Correlation after removing top 67 components: 0.1437
# Adjusted Correlation after removing top 68 components: 0.1049
# Adjusted Correlation after removing top 69 components: 0.0091
# Adjusted Correlation after removing top 70 components: 0.0663
# Adjusted Correlation after removing top 71 components: 0.1327
# Adjusted Correlation after removing top 72 components: 0.1194
# Adjusted Correlation after removing top 73 components: 0.1912
# Adjusted Correlation after removing top 74 components: 0.2019
# Adjusted Correlation after removing top 75 components: 0.1798
# Adjusted Correlation after removing top 76 components: 0.1224
# Adjusted Correlation after removing top 77 components: 0.1012
# Adjusted Correlation after removing top 78 components: 0.1049
# Adjusted Correlation after removing top 79 components: 0.0919
# Adjusted Correlation after removing top 80 components: 0.0879
# Adjusted Correlation after removing top 81 components: 0.0855
# Adjusted Correlation after removing top 82 components: 0.1164
# Adjusted Correlation after removing top 83 components: 0.1325
# Adjusted Correlation after removing top 84 components: 0.1247
# Adjusted Correlation after removing top 85 components: 0.0591
# Adjusted Correlation after removing top 86 components: 0.0954
# Adjusted Correlation after removing top 87 components: 0.1131
# Adjusted Correlation after removing top 88 components: 0.0796
# Adjusted Correlation after removing top 89 components: 0.0972
# Adjusted Correlation after removing top 90 components: 0.1127
# Adjusted Correlation after removing top 91 components: 0.1242
# Adjusted Correlation after removing top 92 components: 0.1305
# Adjusted Correlation after removing top 93 components: 0.1206
# Adjusted Correlation after removing top 94 components: 0.1154
# Adjusted Correlation after removing top 95 components: 0.0687
# Adjusted Correlation after removing top 96 components: 0.0992
# Adjusted Correlation after removing top 97 components: 0.1221
# Adjusted Correlation after removing top 98 components: 0.1528
# Adjusted Correlation after removing top 99 components: 0.1744
# Adjusted Correlation after removing top 100 components: 0.1597
# Adjusted Correlation after removing top 101 components: 0.1220
# Adjusted Correlation after removing top 102 components: 0.0430
# Adjusted Correlation after removing top 103 components: 0.1194
# Adjusted Correlation after removing top 104 components: 0.1134
# Adjusted Correlation after removing top 105 components: 0.0328
# Adjusted Correlation after removing top 106 components: 0.0273
# Adjusted Correlation after removing top 107 components: 0.0508
# Adjusted Correlation after removing top 108 components: 0.0887
# Adjusted Correlation after removing top 109 components: 0.1500
# Adjusted Correlation after removing top 110 components: 0.1551
# Adjusted Correlation after removing top 111 components: 0.1257
# Adjusted Correlation after removing top 112 components: 0.1369
# Adjusted Correlation after removing top 113 components: 0.1182
# Adjusted Correlation after removing top 114 components: 0.1228
# Adjusted Correlation after removing top 115 components: 0.1136
# Adjusted Correlation after removing top 116 components: 0.0977
# Adjusted Correlation after removing top 117 components: 0.1742
# Adjusted Correlation after removing top 118 components: 0.1512
# Adjusted Correlation after removing top 119 components: 0.0839
# Adjusted Correlation after removing top 120 components: 0.0957
# Adjusted Correlation after removing top 121 components: 0.1182
# Adjusted Correlation after removing top 122 components: 0.0759
# Adjusted Correlation after removing top 123 components: 0.1386
# Adjusted Correlation after removing top 124 components: 0.1107
# Adjusted Correlation after removing top 125 components: 0.0538
# Adjusted Correlation after removing top 126 components: 0.1226
# Adjusted Correlation after removing top 127 components: 0.0801
# Adjusted Correlation after removing top 128 components: 0.1146
# Adjusted Correlation after removing top 129 components: 0.1262
# Adjusted Correlation after removing top 130 components: 0.1309
# Adjusted Correlation after removing top 131 components: 0.1011
# Adjusted Correlation after removing top 132 components: 0.0729
# Adjusted Correlation after removing top 133 components: 0.1086
# Adjusted Correlation after removing top 134 components: 0.1554
# Adjusted Correlation after removing top 135 components: 0.1725
# Adjusted Correlation after removing top 136 components: 0.1850
# Adjusted Correlation after removing top 137 components: 0.1536
# Adjusted Correlation after removing top 138 components: 0.1289
# Adjusted Correlation after removing top 139 components: 0.1116
# Adjusted Correlation after removing top 140 components: 0.0947
# Adjusted Correlation after removing top 141 components: 0.1113
# Adjusted Correlation after removing top 142 components: 0.1414
# Adjusted Correlation after removing top 143 components: 0.1595
# Adjusted Correlation after removing top 144 components: 0.1387
# Adjusted Correlation after removing top 145 components: 0.1565
# Adjusted Correlation after removing top 146 components: 0.1324
# Adjusted Correlation after removing top 147 components: 0.1070
# Adjusted Correlation after removing top 148 components: 0.0982
# Adjusted Correlation after removing top 149 components: 0.0986
# Adjusted Correlation after removing top 150 components: 0.1052
# Adjusted Correlation after removing top 151 components: 0.0678
# Adjusted Correlation after removing top 152 components: 0.0743
# Adjusted Correlation after removing top 153 components: 0.1444
# Adjusted Correlation after removing top 154 components: 0.1493
# Adjusted Correlation after removing top 155 components: 0.0994
# Adjusted Correlation after removing top 156 components: 0.0802
# Adjusted Correlation after removing top 157 components: 0.0701
# Adjusted Correlation after removing top 158 components: 0.0806
# Adjusted Correlation after removing top 159 components: 0.0740
# Adjusted Correlation after removing top 160 components: 0.1474
# Adjusted Correlation after removing top 161 components: 0.1402
# Adjusted Correlation after removing top 162 components: 0.1299
# Adjusted Correlation after removing top 163 components: 0.1086
# Adjusted Correlation after removing top 164 components: 0.1390
# Adjusted Correlation after removing top 165 components: 0.1149
# Adjusted Correlation after removing top 166 components: 0.0609
# Adjusted Correlation after removing top 167 components: 0.0324
# Adjusted Correlation after removing top 168 components: 0.1007
# Adjusted Correlation after removing top 169 components: 0.0970
# Adjusted Correlation after removing top 170 components: 0.1158
# Adjusted Correlation after removing top 171 components: 0.1198
# Adjusted Correlation after removing top 172 components: 0.0865
# Adjusted Correlation after removing top 173 components: 0.1256
# Adjusted Correlation after removing top 174 components: 0.0861
# Adjusted Correlation after removing top 175 components: 0.0874
# Adjusted Correlation after removing top 176 components: 0.1128
# Adjusted Correlation after removing top 177 components: 0.0593
# Adjusted Correlation after removing top 178 components: 0.0453
# Adjusted Correlation after removing top 179 components: 0.0941
# Adjusted Correlation after removing top 180 components: 0.1410
# Adjusted Correlation after removing top 181 components: 0.1050
# Adjusted Correlation after removing top 182 components: 0.0922
# Adjusted Correlation after removing top 183 components: 0.0717
# Adjusted Correlation after removing top 184 components: 0.0752
# Adjusted Correlation after removing top 185 components: 0.1102
# Adjusted Correlation after removing top 186 components: 0.0945
# Adjusted Correlation after removing top 187 components: 0.1331
# Adjusted Correlation after removing top 188 components: 0.0925
# Adjusted Correlation after removing top 189 components: 0.1257
# Adjusted Correlation after removing top 190 components: 0.1387
# Adjusted Correlation after removing top 191 components: 0.1026
# Adjusted Correlation after removing top 192 components: 0.1182
# Adjusted Correlation after removing top 193 components: 0.1569
# Adjusted Correlation after removing top 194 components: 0.1239
# Adjusted Correlation after removing top 195 components: 0.0803
# Adjusted Correlation after removing top 196 components: 0.1069
# Adjusted Correlation after removing top 197 components: 0.0930
# Adjusted Correlation after removing top 198 components: 0.1401
# Adjusted Correlation after removing top 199 components: 0.0998
# Adjusted Correlation after removing top 200 components: 0.0787
# Adjusted Correlation after removing top 201 components: 0.0968
# Adjusted Correlation after removing top 202 components: 0.0612
# Adjusted Correlation after removing top 203 components: 0.1006
# Adjusted Correlation after removing top 204 components: 0.1279
# Adjusted Correlation after removing top 205 components: 0.0949
# Adjusted Correlation after removing top 206 components: 0.1677
# Adjusted Correlation after removing top 207 components: 0.1236
# Adjusted Correlation after removing top 208 components: 0.1028
# Adjusted Correlation after removing top 209 components: 0.1031
# Adjusted Correlation after removing top 210 components: 0.0878
# Adjusted Correlation after removing top 211 components: 0.1170
# Adjusted Correlation after removing top 212 components: 0.1356
# Adjusted Correlation after removing top 213 components: 0.0866
# Adjusted Correlation after removing top 214 components: 0.1139
# Adjusted Correlation after removing top 215 components: 0.1166
# Adjusted Correlation after removing top 216 components: 0.1523
# Adjusted Correlation after removing top 217 components: 0.1433
# Adjusted Correlation after removing top 218 components: 0.1033
# Adjusted Correlation after removing top 219 components: 0.0782
# Adjusted Correlation after removing top 220 components: 0.0560
# Adjusted Correlation after removing top 221 components: 0.0662
# Adjusted Correlation after removing top 222 components: 0.0890
# Adjusted Correlation after removing top 223 components: 0.1044
# Adjusted Correlation after removing top 224 components: 0.0614
# Adjusted Correlation after removing top 225 components: 0.0867
# Adjusted Correlation after removing top 226 components: 0.0667
# Adjusted Correlation after removing top 227 components: 0.1125
# Adjusted Correlation after removing top 228 components: 0.1238
# Adjusted Correlation after removing top 229 components: 0.0593
# Adjusted Correlation after removing top 230 components: 0.0723
# Adjusted Correlation after removing top 231 components: 0.0088
# Adjusted Correlation after removing top 232 components: 0.0580
# Adjusted Correlation after removing top 233 components: 0.0853
# Adjusted Correlation after removing top 234 components: 0.0707
# Adjusted Correlation after removing top 235 components: 0.0211
# Adjusted Correlation after removing top 236 components: 0.0352
# Adjusted Correlation after removing top 237 components: 0.0963
# Adjusted Correlation after removing top 238 components: 0.1278
# Adjusted Correlation after removing top 239 components: 0.0943
# Adjusted Correlation after removing top 240 components: 0.0922
# Adjusted Correlation after removing top 241 components: 0.0853
# Adjusted Correlation after removing top 242 components: 0.1040
# Adjusted Correlation after removing top 243 components: 0.1151
# Adjusted Correlation after removing top 244 components: 0.0551
# Adjusted Correlation after removing top 245 components: 0.0687
# Adjusted Correlation after removing top 246 components: 0.0707
# Adjusted Correlation after removing top 247 components: 0.1144
# Adjusted Correlation after removing top 248 components: 0.1137
# Adjusted Correlation after removing top 249 components: 0.0929
# Adjusted Correlation after removing top 250 components: 0.0976
# Adjusted Correlation after removing top 251 components: 0.1023
# Adjusted Correlation after removing top 252 components: 0.1420
# Adjusted Correlation after removing top 253 components: 0.1100
# Adjusted Correlation after removing top 254 components: 0.0744
# Adjusted Correlation after removing top 255 components: 0.0826
# Adjusted Correlation after removing top 256 components: 0.0864
# Adjusted Correlation after removing top 257 components: 0.1258
# Adjusted Correlation after removing top 258 components: 0.1064
# Adjusted Correlation after removing top 259 components: 0.0945
# Adjusted Correlation after removing top 260 components: 0.1083
# Adjusted Correlation after removing top 261 components: 0.1484
# Adjusted Correlation after removing top 262 components: 0.0919
# Adjusted Correlation after removing top 263 components: 0.1117
# Adjusted Correlation after removing top 264 components: 0.1803
# Adjusted Correlation after removing top 265 components: 0.1518
# Adjusted Correlation after removing top 266 components: 0.0886
# Adjusted Correlation after removing top 267 components: 0.1331
# Adjusted Correlation after removing top 268 components: 0.0864
# Adjusted Correlation after removing top 269 components: 0.0798
# Adjusted Correlation after removing top 270 components: 0.0569
# Adjusted Correlation after removing top 271 components: 0.0716
# Adjusted Correlation after removing top 272 components: 0.1295
# Adjusted Correlation after removing top 273 components: 0.1373
# Adjusted Correlation after removing top 274 components: 0.0485
# Adjusted Correlation after removing top 275 components: 0.0856
# Adjusted Correlation after removing top 276 components: 0.1189
# Adjusted Correlation after removing top 277 components: 0.0929
# Adjusted Correlation after removing top 278 components: 0.0689
# Adjusted Correlation after removing top 279 components: 0.0600
# Adjusted Correlation after removing top 280 components: 0.0635
# Adjusted Correlation after removing top 281 components: 0.1209
# Adjusted Correlation after removing top 282 components: 0.1045
# Adjusted Correlation after removing top 283 components: 0.0896
# Adjusted Correlation after removing top 284 components: 0.0758
# Adjusted Correlation after removing top 285 components: 0.0481
# Adjusted Correlation after removing top 286 components: 0.0814
# Adjusted Correlation after removing top 287 components: 0.1514
# Adjusted Correlation after removing top 288 components: 0.1057
# Adjusted Correlation after removing top 289 components: 0.1346
# Adjusted Correlation after removing top 290 components: 0.1084
# Adjusted Correlation after removing top 291 components: 0.0042
# Adjusted Correlation after removing top 292 components: 0.0484
# Adjusted Correlation after removing top 293 components: 0.0760
# Adjusted Correlation after removing top 294 components: 0.0682
# Adjusted Correlation after removing top 295 components: 0.0551
# Adjusted Correlation after removing top 296 components: 0.0647
# Adjusted Correlation after removing top 297 components: 0.0557
# Adjusted Correlation after removing top 298 components: 0.0498
# Best Spearman Correlation with Task-Driven Reduction: 0.2073
#
# Final Optimized Spearman Correlation at 2D: 0.2073

# %%
# Save the 2D embeddings with word labels to a CSV file
def save_embeddings_to_csv(words, embeddings, file_path):
    print(f"Saving 2D embeddings to {file_path}...")
    df = pd.DataFrame(embeddings, columns=['x', 'y'])
    df['word'] = words
    df.to_csv(file_path, index=False)
    print("2D embeddings saved successfully.")

# %%
# Get words and their high-dimensional embeddings
words = original_model.index_to_key  # List of words in vocabulary
file_path="TruncatedSVD_FastText_2d_word_embeddings.csv"
# Save the embeddings and words to a CSV file
save_embeddings_to_csv(words, optimized_embeddings, file_path)
# Out:
# Saving 2D embeddings to TruncatedSVD_FastText_2d_word_embeddings.csv...
# 2D embeddings saved successfully.

# %%
import matplotlib.pyplot as plt
import re

def extract_and_plot_data(filepath):
    """
    Extracts data from a text file, groups it, calculates averages, and plots the results.

    Args:
        filepath: The path to the text file.
    """

    correlations = []
    with open(filepath, 'r') as f:
        for line in f:
            match = re.search(r"Adjusted Correlation after removing top (\d+) components: (-?\d+\.\d+)", line)
            if match:
                num_components = int(match.group(1))
                correlation = float(match.group(2))
                correlations.append((num_components, correlation))

    # Group data and calculate averages
    group_averages = []
    group_labels = []
    for i in range(0, 300, 30):  # Changed step size from 50 to 30
        group = [corr for comp, corr in correlations if i <= comp < i + 30]  # Changed range from 50 to 30
        if group:  # Check if the group is not empty
            average_correlation = sum(group) / len(group)
            group_averages.append(average_correlation)
            group_labels.append(f"{i}-{min(i + 29, 299)}")  # Changed from i + 49 to i + 29

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(group_labels, group_averages, marker='o', linestyle='-')
    plt.xlabel("Number of Components Removed (Groups)")
    plt.ylabel("Average Adjusted Correlation")
    plt.title("Average Adjusted Correlation vs. Number of Components Removed")
    plt.grid(True)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()
    plt.show()

# Example usage:
filepath = '/teamspace/studios/this_studio/TRUNCATED SVD/TruncatedSVD_FastText_data.txt'  # Replace with your file path
extract_and_plot_data(filepath)

# %%
import matplotlib.pyplot as plt
import re

def extract_data(filepath):
    """
    Extracts data from a text file and returns the correlations.

    Args:
        filepath: The path to the text file.
    
    Returns:
        A list of tuples containing (num_components, correlation).
    """
    correlations = []
    with open(filepath, 'r') as f:
        for line in f:
            match = re.search(r"Adjusted Correlation after removing top (\d+) components: (-?\d+\.\d+)", line)
            if match:
                num_components = int(match.group(1))
                correlation = float(match.group(2))
                correlations.append((num_components, correlation))
    return correlations

def calculate_group_averages(correlations):
    """
    Groups data and calculates averages.
    
    Args:
        correlations: A list of tuples containing (num_components, correlation).
    
    Returns:
        Two lists: group_labels and group_averages.
    """
    group_averages = []
    group_labels = []
    for i in range(0, 300, 30):  # Step size of 30
        group = [corr for comp, corr in correlations if i <= comp < i + 30]
        if group:  # Check if the group is not empty
            average_correlation = sum(group) / len(group)
            group_averages.append(average_correlation)
            group_labels.append(f"{i}-{min(i + 29, 299)}")
    
    return group_labels, group_averages

def plot_multiple_models(filepaths, model_names, colors):
    """
    Extracts data from multiple files, calculates averages, and plots the results with different colors.

    Args:
        filepaths: A list of paths to the text files.
        model_names: A list of model names for the legend.
        colors: A list of colors for the lines.
    """
    plt.figure(figsize=(12, 7))
    
    for filepath, model_name, color in zip(filepaths, model_names, colors):
        correlations = extract_data(filepath)
        group_labels, group_averages = calculate_group_averages(correlations)
        
        plt.plot(group_labels, group_averages, marker='o', linestyle='-', color=color, label=model_name)
        print(group_averages)
    
    plt.xlabel("Number of Components Removed (Groups)")
    plt.ylabel("Average Adjusted Correlation")
    plt.title("Average Adjusted Correlation vs. Number of Components Removed")
    plt.grid(True)
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.legend(loc='best')  # Add legend
    plt.tight_layout()
    plt.show()

# Example usage:
filepaths = [
    '/teamspace/studios/this_studio/TRUNCATED SVD/TruncatedSVD_FastText_data.txt',
    '/teamspace/studios/this_studio/TRUNCATED SVD/TruncatedSVD_Glove_data.txt',
    '/teamspace/studios/this_studio/TRUNCATED SVD/TruncatedSVD_Word2Vec_data.txt'
]
model_names = ['FastText', 'GloVe', 'Word2Vec']
colors = ['blue', 'red', 'green']  # Different colors for each model

plot_multiple_models(filepaths, model_names, colors)
# Out:
# [0.10326666666666666, 0.11995666666666664, 0.11034999999999999, 0.11356666666666664, 0.11983999999999999, 0.09830000000000001, 0.10862666666666668, 0.08768, 0.10381333333333333, 0.08193448275862068]
# [0.06550333333333333, 0.06730666666666665, 0.08476666666666664, 0.08780333333333333, 0.11688000000000001, 0.10347, 0.11521666666666666, 0.07126666666666666, 0.03280333333333333, -0.009348275862068968]
# [0.07160333333333332, 0.09807333333333332, 0.10523999999999999, 0.11682999999999999, 0.1016766666666667, 0.10884666666666666, 0.11390999999999998, 0.10794333333333331, 0.10920666666666666, 0.12808275862068963]
