# %%
import numpy as np
import cupy as cp
from cuml.decomposition import TruncatedSVD
from scipy.stats import spearmanr
import os
import gensim.downloader as api

# %%
class ReducedEmbeddingModel:
    def __init__(self, vectors, index_to_key):
        self.vectors = vectors
        self.index_to_key = index_to_key
        self.key_to_index = {word: idx for idx, word in enumerate(index_to_key)}
    
    def __getitem__(self, word):
        if word in self.key_to_index:
            return self.vectors[self.key_to_index[word]]
        raise KeyError(f"Word '{word}' not found in vocabulary")
    
    def __contains__(self, word):
        return word in self.key_to_index

# Load the pre-trained FastText model
def load_fasttext_model():
    os.environ["GENSIM_DATA_DIR"] = "/teamspace/studios/this_studio/gensim-data"
    fasttext_model = api.load('fasttext-wiki-news-subwords-300')
    return fasttext_model
    
# Load SimLex-999 word similarity data
def load_simlex_999(file_path):
    """Loads SimLex-999 and returns word pairs with similarity scores."""
    data = []
    with open(file_path, 'r') as file:
        next(file)  # Skip header
        for line in file:
            parts = line.strip().split('\t')
            word1, word2, similarity_score = parts[0], parts[1], float(parts[3])
            data.append((word1, word2, similarity_score))
    return data

# Cosine similarity function for similarity evaluation
def cosine_similarity(v1, v2):
    norm1 = np.linalg.norm(v1)
    norm2 = np.linalg.norm(v2)
    if norm1 == 0 or norm2 == 0:
        return 0
    return np.dot(v1, v2) / (norm1 * norm2)

# Evaluate embeddings on the word similarity data
def evaluate_embeddings(model, word_pairs):
    
    predicted_scores = []
    true_scores = []

    model_dict = {}
    for i in range(len(model.index_to_key)):
        model_dict[model.index_to_key[i]] = model.vectors[i]
    
    for word1, word2, true_score in word_pairs:
        if word1 in model_dict and word2 in model_dict:
            sim_score = cosine_similarity(model_dict[word1], model_dict[word2])
            predicted_scores.append(sim_score)
            true_scores.append(true_score)
    
    # Calculate Spearman correlation for word similarity performance
    correlation, _ = spearmanr(true_scores, predicted_scores)
    return correlation

def task_driven_dimensionality_reduction(embeddings, target_dim, word_pairs, model):
    """
    Reduces dimensions using TruncatedSVD with optimization for similarity, similar to PCA approach.
    """
    cu_embeddings = cp.asarray(embeddings)
    original_dim = cu_embeddings.shape[1]
    
    best_correlation = -1.0
    best_embeddings = None
    results = []

    # Perform initial TruncatedSVD to a larger dimension to capture more variance initially
    initial_n_components = min(original_dim, 300)  # Example: Reduce to 300 initially
    svd = TruncatedSVD(n_components=initial_n_components, algorithm="full")
    reduced_embeddings = svd.fit_transform(cu_embeddings)

    for num_remove in range(initial_n_components - target_dim + 1):
        # Remove top components
        temp_embeddings = reduced_embeddings[:, num_remove:]

        # Further reduce to target_dim if necessary
        if temp_embeddings.shape[1] > target_dim:
            svd_final = TruncatedSVD(n_components=target_dim, algorithm="full")
            final_embeddings = svd_final.fit_transform(temp_embeddings)
        else:
            final_embeddings = temp_embeddings
        
        final_embeddings_np = cp.asnumpy(final_embeddings)

        # Create a reduced model for evaluation
        reduced_model = ReducedEmbeddingModel(final_embeddings_np, model.index_to_key)

        # Evaluate
        correlation = evaluate_embeddings(reduced_model, word_pairs)
        results.append((num_remove, correlation))
        print(f"Removed top {num_remove} components, new dim = {final_embeddings.shape[1]}, correlation = {correlation:.4f}")

        if correlation > best_correlation:
            best_correlation = correlation
            best_embeddings = final_embeddings_np

    print(f"\nBest correlation: {best_correlation:.4f}")
    return best_embeddings, best_correlation, results

# %%
simlex_file_path = '/teamspace/studios/pca/SimLex-999.txt'  # Update this path to your SimLex-999 file
target_dim = 2

print("Loading FastText model...")
original_model = load_fasttext_model()

# Load word similarity dataset
word_pairs = load_simlex_999(simlex_file_path)
# Out:
# Loading FastText model...

# %%
# Perform task-driven dimensionality reduction with TruncatedSVD and top component removal
optimized_embeddings, best_correlation, results = task_driven_dimensionality_reduction(
    original_model.vectors,
    target_dim=target_dim,
    word_pairs=word_pairs,
    model=original_model
)
# Out:
# Removed top 0 components, new dim = 2, correlation = 0.0844
# Removed top 1 components, new dim = 2, correlation = 0.0644
# Removed top 2 components, new dim = 2, correlation = 0.0487
# Removed top 3 components, new dim = 2, correlation = 0.0486
# Removed top 4 components, new dim = 2, correlation = 0.0639
# Removed top 5 components, new dim = 2, correlation = 0.1008
# Removed top 6 components, new dim = 2, correlation = 0.1598
# Removed top 7 components, new dim = 2, correlation = 0.1745
# Removed top 8 components, new dim = 2, correlation = 0.1512
# Removed top 9 components, new dim = 2, correlation = 0.1470
# Removed top 10 components, new dim = 2, correlation = 0.0874
# Removed top 11 components, new dim = 2, correlation = 0.0502
# Removed top 12 components, new dim = 2, correlation = 0.0657
# Removed top 13 components, new dim = 2, correlation = 0.0376
# Removed top 14 components, new dim = 2, correlation = 0.0339
# Removed top 15 components, new dim = 2, correlation = 0.0516
# Removed top 16 components, new dim = 2, correlation = 0.1359
# Removed top 17 components, new dim = 2, correlation = 0.1371
# Removed top 18 components, new dim = 2, correlation = 0.1248
# Removed top 19 components, new dim = 2, correlation = 0.1588
# Removed top 20 components, new dim = 2, correlation = 0.1492
# Removed top 21 components, new dim = 2, correlation = 0.1444
# Removed top 22 components, new dim = 2, correlation = 0.1409
# Removed top 23 components, new dim = 2, correlation = 0.1130
# Removed top 24 components, new dim = 2, correlation = 0.1370
# Removed top 25 components, new dim = 2, correlation = 0.0653
# Removed top 26 components, new dim = 2, correlation = 0.0941
# Removed top 27 components, new dim = 2, correlation = 0.0987
# Removed top 28 components, new dim = 2, correlation = 0.1142
# Removed top 29 components, new dim = 2, correlation = 0.1149
# Removed top 30 components, new dim = 2, correlation = 0.1164
# Removed top 31 components, new dim = 2, correlation = 0.1114
# Removed top 32 components, new dim = 2, correlation = 0.1673
# Removed top 33 components, new dim = 2, correlation = 0.1577
# Removed top 34 components, new dim = 2, correlation = 0.1169
# Removed top 35 components, new dim = 2, correlation = 0.0785
# Removed top 36 components, new dim = 2, correlation = 0.1129
# Removed top 37 components, new dim = 2, correlation = 0.1432
# Removed top 38 components, new dim = 2, correlation = 0.0257
# Removed top 39 components, new dim = 2, correlation = 0.1252
# Removed top 40 components, new dim = 2, correlation = 0.2046
# Removed top 41 components, new dim = 2, correlation = 0.1394
# Removed top 42 components, new dim = 2, correlation = 0.0972
# Removed top 43 components, new dim = 2, correlation = 0.0908
# Removed top 44 components, new dim = 2, correlation = 0.0388
# Removed top 45 components, new dim = 2, correlation = 0.0864
# Removed top 46 components, new dim = 2, correlation = 0.2073
# Removed top 47 components, new dim = 2, correlation = 0.1552
# Removed top 48 components, new dim = 2, correlation = 0.1691
# Removed top 49 components, new dim = 2, correlation = 0.1521
# Removed top 50 components, new dim = 2, correlation = 0.1482
# Removed top 51 components, new dim = 2, correlation = 0.1189
# Removed top 52 components, new dim = 2, correlation = 0.1260
# Removed top 53 components, new dim = 2, correlation = 0.0713
# Removed top 54 components, new dim = 2, correlation = 0.1323
# Removed top 55 components, new dim = 2, correlation = 0.1186
# Removed top 56 components, new dim = 2, correlation = 0.0821
# Removed top 57 components, new dim = 2, correlation = 0.0717
# Removed top 58 components, new dim = 2, correlation = 0.0950
# Removed top 59 components, new dim = 2, correlation = 0.1386
# Removed top 60 components, new dim = 2, correlation = 0.1755
# Removed top 61 components, new dim = 2, correlation = 0.0801
# Removed top 62 components, new dim = 2, correlation = 0.0697
# Removed top 63 components, new dim = 2, correlation = 0.1548
# Removed top 64 components, new dim = 2, correlation = 0.1241
# Removed top 65 components, new dim = 2, correlation = 0.0795
# Removed top 66 components, new dim = 2, correlation = 0.0661
# Removed top 67 components, new dim = 2, correlation = 0.1437
# Removed top 68 components, new dim = 2, correlation = 0.1049
# Removed top 69 components, new dim = 2, correlation = 0.0091
# Removed top 70 components, new dim = 2, correlation = 0.0663
# Removed top 71 components, new dim = 2, correlation = 0.1328
# Removed top 72 components, new dim = 2, correlation = 0.1198
# Removed top 73 components, new dim = 2, correlation = 0.1911
# Removed top 74 components, new dim = 2, correlation = 0.2020
# Removed top 75 components, new dim = 2, correlation = 0.1798
# Removed top 76 components, new dim = 2, correlation = 0.1224
# Removed top 77 components, new dim = 2, correlation = 0.1011
# Removed top 78 components, new dim = 2, correlation = 0.1050
# Removed top 79 components, new dim = 2, correlation = 0.0920
# Removed top 80 components, new dim = 2, correlation = 0.0879
# Removed top 81 components, new dim = 2, correlation = 0.0856
# Removed top 82 components, new dim = 2, correlation = 0.1164
# Removed top 83 components, new dim = 2, correlation = 0.1324
# Removed top 84 components, new dim = 2, correlation = 0.1247
# Removed top 85 components, new dim = 2, correlation = 0.0591
# Removed top 86 components, new dim = 2, correlation = 0.0952
# Removed top 87 components, new dim = 2, correlation = 0.1131
# Removed top 88 components, new dim = 2, correlation = 0.0796
# Removed top 89 components, new dim = 2, correlation = 0.0973
# Removed top 90 components, new dim = 2, correlation = 0.1126
# Removed top 91 components, new dim = 2, correlation = 0.1242
# Removed top 92 components, new dim = 2, correlation = 0.1304
# Removed top 93 components, new dim = 2, correlation = 0.1206
# Removed top 94 components, new dim = 2, correlation = 0.1151
# Removed top 95 components, new dim = 2, correlation = 0.0686
# Removed top 96 components, new dim = 2, correlation = 0.0994
# Removed top 97 components, new dim = 2, correlation = 0.1221
# Removed top 98 components, new dim = 2, correlation = 0.1529
# Removed top 99 components, new dim = 2, correlation = 0.1745
# Removed top 100 components, new dim = 2, correlation = 0.1598
# Removed top 101 components, new dim = 2, correlation = 0.1221
# Removed top 102 components, new dim = 2, correlation = 0.0430
# Removed top 103 components, new dim = 2, correlation = 0.1193
# Removed top 104 components, new dim = 2, correlation = 0.1134
# Removed top 105 components, new dim = 2, correlation = 0.0328
# Removed top 106 components, new dim = 2, correlation = 0.0273
# Removed top 107 components, new dim = 2, correlation = 0.0508
# Removed top 108 components, new dim = 2, correlation = 0.0888
# Removed top 109 components, new dim = 2, correlation = 0.1500
# Removed top 110 components, new dim = 2, correlation = 0.1551
# Removed top 111 components, new dim = 2, correlation = 0.1257
# Removed top 112 components, new dim = 2, correlation = 0.1369
# Removed top 113 components, new dim = 2, correlation = 0.1182
# Removed top 114 components, new dim = 2, correlation = 0.1228
# Removed top 115 components, new dim = 2, correlation = 0.1136
# Removed top 116 components, new dim = 2, correlation = 0.0977
# Removed top 117 components, new dim = 2, correlation = 0.1742
# Removed top 118 components, new dim = 2, correlation = 0.1512
# Removed top 119 components, new dim = 2, correlation = 0.0840
# Removed top 120 components, new dim = 2, correlation = 0.0957
# Removed top 121 components, new dim = 2, correlation = 0.1182
# Removed top 122 components, new dim = 2, correlation = 0.0759
# Removed top 123 components, new dim = 2, correlation = 0.1386
# Removed top 124 components, new dim = 2, correlation = 0.1107
# Removed top 125 components, new dim = 2, correlation = 0.0538
# Removed top 126 components, new dim = 2, correlation = 0.1226
# Removed top 127 components, new dim = 2, correlation = 0.0802
# Removed top 128 components, new dim = 2, correlation = 0.1147
# Removed top 129 components, new dim = 2, correlation = 0.1262
# Removed top 130 components, new dim = 2, correlation = 0.1308
# Removed top 131 components, new dim = 2, correlation = 0.1011
# Removed top 132 components, new dim = 2, correlation = 0.0801
# Removed top 133 components, new dim = 2, correlation = 0.1089
# Removed top 134 components, new dim = 2, correlation = 0.1553
# Removed top 135 components, new dim = 2, correlation = 0.1725
# Removed top 136 components, new dim = 2, correlation = 0.1849
# Removed top 137 components, new dim = 2, correlation = 0.1536
# Removed top 138 components, new dim = 2, correlation = 0.1289
# Removed top 139 components, new dim = 2, correlation = 0.1117
# Removed top 140 components, new dim = 2, correlation = 0.0947
# Removed top 141 components, new dim = 2, correlation = 0.1113
# Removed top 142 components, new dim = 2, correlation = 0.1414
# Removed top 143 components, new dim = 2, correlation = 0.1595
# Removed top 144 components, new dim = 2, correlation = 0.1387
# Removed top 145 components, new dim = 2, correlation = 0.1565
# Removed top 146 components, new dim = 2, correlation = 0.1324
# Removed top 147 components, new dim = 2, correlation = 0.1069
# Removed top 148 components, new dim = 2, correlation = 0.0981
# Removed top 149 components, new dim = 2, correlation = 0.0987
# Removed top 150 components, new dim = 2, correlation = 0.1052
# Removed top 151 components, new dim = 2, correlation = 0.0678
# Removed top 152 components, new dim = 2, correlation = 0.0743
# Removed top 153 components, new dim = 2, correlation = 0.1444
# Removed top 154 components, new dim = 2, correlation = 0.1492
# Removed top 155 components, new dim = 2, correlation = 0.0995
# Removed top 156 components, new dim = 2, correlation = 0.0802
# Removed top 157 components, new dim = 2, correlation = 0.0696
# Removed top 158 components, new dim = 2, correlation = 0.0810
# Removed top 159 components, new dim = 2, correlation = 0.0740
# Removed top 160 components, new dim = 2, correlation = 0.1474
# Removed top 161 components, new dim = 2, correlation = 0.1402
# Removed top 162 components, new dim = 2, correlation = 0.1300
# Removed top 163 components, new dim = 2, correlation = 0.1086
# Removed top 164 components, new dim = 2, correlation = 0.1390
# Removed top 165 components, new dim = 2, correlation = 0.1148
# Removed top 166 components, new dim = 2, correlation = 0.0623
# Removed top 167 components, new dim = 2, correlation = 0.0294
# Removed top 168 components, new dim = 2, correlation = 0.1007
# Removed top 169 components, new dim = 2, correlation = 0.0970
# Removed top 170 components, new dim = 2, correlation = 0.1158
# Removed top 171 components, new dim = 2, correlation = 0.1197
# Removed top 172 components, new dim = 2, correlation = 0.0865
# Removed top 173 components, new dim = 2, correlation = 0.1256
# Removed top 174 components, new dim = 2, correlation = 0.0862
# Removed top 175 components, new dim = 2, correlation = 0.0874
# Removed top 176 components, new dim = 2, correlation = 0.1127
# Removed top 177 components, new dim = 2, correlation = 0.0592
# Removed top 178 components, new dim = 2, correlation = 0.0453
# Removed top 179 components, new dim = 2, correlation = 0.0941
# Removed top 180 components, new dim = 2, correlation = 0.1411
# Removed top 181 components, new dim = 2, correlation = 0.1051
# Removed top 182 components, new dim = 2, correlation = 0.0922
# Removed top 183 components, new dim = 2, correlation = 0.0717
# Removed top 184 components, new dim = 2, correlation = 0.0752
# Removed top 185 components, new dim = 2, correlation = 0.1116
# Removed top 186 components, new dim = 2, correlation = 0.1004
# Removed top 187 components, new dim = 2, correlation = 0.1329
# Removed top 188 components, new dim = 2, correlation = 0.0925
# Removed top 189 components, new dim = 2, correlation = 0.1257
# Removed top 190 components, new dim = 2, correlation = 0.1387
# Removed top 191 components, new dim = 2, correlation = 0.1026
# Removed top 192 components, new dim = 2, correlation = 0.1181
# Removed top 193 components, new dim = 2, correlation = 0.1568
# Removed top 194 components, new dim = 2, correlation = 0.1237
# Removed top 195 components, new dim = 2, correlation = 0.0805
# Removed top 196 components, new dim = 2, correlation = 0.1070
# Removed top 197 components, new dim = 2, correlation = 0.0930
# Removed top 198 components, new dim = 2, correlation = 0.1401
# Removed top 199 components, new dim = 2, correlation = 0.0998
# Removed top 200 components, new dim = 2, correlation = 0.0786
# Removed top 201 components, new dim = 2, correlation = 0.0969
# Removed top 202 components, new dim = 2, correlation = 0.0611
# Removed top 203 components, new dim = 2, correlation = 0.1005
# Removed top 204 components, new dim = 2, correlation = 0.1279
# Removed top 205 components, new dim = 2, correlation = 0.0949
# Removed top 206 components, new dim = 2, correlation = 0.1677
# Removed top 207 components, new dim = 2, correlation = 0.1236
# Removed top 208 components, new dim = 2, correlation = 0.1029
# Removed top 209 components, new dim = 2, correlation = 0.1031
# Removed top 210 components, new dim = 2, correlation = 0.0878
# Removed top 211 components, new dim = 2, correlation = 0.1169
# Removed top 212 components, new dim = 2, correlation = 0.1356
# Removed top 213 components, new dim = 2, correlation = 0.0866
# Removed top 214 components, new dim = 2, correlation = 0.1139
# Removed top 215 components, new dim = 2, correlation = 0.1166
# Removed top 216 components, new dim = 2, correlation = 0.1523
# Removed top 217 components, new dim = 2, correlation = 0.1433
# Removed top 218 components, new dim = 2, correlation = 0.1033
# Removed top 219 components, new dim = 2, correlation = 0.0781
# Removed top 220 components, new dim = 2, correlation = 0.0559
# Removed top 221 components, new dim = 2, correlation = 0.0663
# Removed top 222 components, new dim = 2, correlation = 0.0890
# Removed top 223 components, new dim = 2, correlation = 0.1043
# Removed top 224 components, new dim = 2, correlation = 0.0614
# Removed top 225 components, new dim = 2, correlation = 0.0870
# Removed top 226 components, new dim = 2, correlation = 0.0667
# Removed top 227 components, new dim = 2, correlation = 0.1124
# Removed top 228 components, new dim = 2, correlation = 0.1239
# Removed top 229 components, new dim = 2, correlation = 0.0593
# Removed top 230 components, new dim = 2, correlation = 0.0723
# Removed top 231 components, new dim = 2, correlation = 0.0089
# Removed top 232 components, new dim = 2, correlation = 0.0579
# Removed top 233 components, new dim = 2, correlation = 0.0854
# Removed top 234 components, new dim = 2, correlation = 0.0706
# Removed top 235 components, new dim = 2, correlation = 0.0211
# Removed top 236 components, new dim = 2, correlation = 0.0347
# Removed top 237 components, new dim = 2, correlation = 0.0963
# Removed top 238 components, new dim = 2, correlation = 0.1277
# Removed top 239 components, new dim = 2, correlation = 0.0969
# Removed top 240 components, new dim = 2, correlation = 0.0920
# Removed top 241 components, new dim = 2, correlation = 0.0853
# Removed top 242 components, new dim = 2, correlation = 0.1040
# Removed top 243 components, new dim = 2, correlation = 0.1151
# Removed top 244 components, new dim = 2, correlation = 0.0551
# Removed top 245 components, new dim = 2, correlation = 0.0688
# Removed top 246 components, new dim = 2, correlation = 0.0709
# Removed top 247 components, new dim = 2, correlation = 0.1133
# Removed top 248 components, new dim = 2, correlation = 0.1125
# Removed top 249 components, new dim = 2, correlation = 0.0941
# Removed top 250 components, new dim = 2, correlation = 0.0976
# Removed top 251 components, new dim = 2, correlation = 0.1023
# Removed top 252 components, new dim = 2, correlation = 0.1420
# Removed top 253 components, new dim = 2, correlation = 0.1100
# Removed top 254 components, new dim = 2, correlation = 0.0746
# Removed top 255 components, new dim = 2, correlation = 0.0831
# Removed top 256 components, new dim = 2, correlation = 0.0809
# Removed top 257 components, new dim = 2, correlation = 0.1265
# Removed top 258 components, new dim = 2, correlation = 0.1072
# Removed top 259 components, new dim = 2, correlation = 0.0943
# Removed top 260 components, new dim = 2, correlation = 0.1087
# Removed top 261 components, new dim = 2, correlation = 0.1483
# Removed top 262 components, new dim = 2, correlation = 0.0919
# Removed top 263 components, new dim = 2, correlation = 0.1120
# Removed top 264 components, new dim = 2, correlation = 0.1803
# Removed top 265 components, new dim = 2, correlation = 0.1519
# Removed top 266 components, new dim = 2, correlation = 0.0888
# Removed top 267 components, new dim = 2, correlation = 0.1327
# Removed top 268 components, new dim = 2, correlation = 0.0862
# Removed top 269 components, new dim = 2, correlation = 0.0800
# Removed top 270 components, new dim = 2, correlation = 0.0570
# Removed top 271 components, new dim = 2, correlation = 0.0716
# Removed top 272 components, new dim = 2, correlation = 0.1296
# Removed top 273 components, new dim = 2, correlation = 0.1372
# Removed top 274 components, new dim = 2, correlation = 0.0637
# Removed top 275 components, new dim = 2, correlation = 0.0858
# Removed top 276 components, new dim = 2, correlation = 0.1190
# Removed top 277 components, new dim = 2, correlation = 0.0930
# Removed top 278 components, new dim = 2, correlation = 0.0689
# Removed top 279 components, new dim = 2, correlation = 0.0603
# Removed top 280 components, new dim = 2, correlation = 0.0634
# Removed top 281 components, new dim = 2, correlation = 0.1208
# Removed top 282 components, new dim = 2, correlation = 0.1043
# Removed top 283 components, new dim = 2, correlation = 0.0890
# Removed top 284 components, new dim = 2, correlation = 0.0767
# Removed top 285 components, new dim = 2, correlation = 0.0480
# Removed top 286 components, new dim = 2, correlation = 0.0814
# Removed top 287 components, new dim = 2, correlation = 0.1514
# Removed top 288 components, new dim = 2, correlation = 0.1057
# Removed top 289 components, new dim = 2, correlation = 0.1336
# Removed top 290 components, new dim = 2, correlation = 0.1084
# Removed top 291 components, new dim = 2, correlation = 0.0041
# Removed top 292 components, new dim = 2, correlation = 0.0484
# Removed top 293 components, new dim = 2, correlation = 0.0760
# Removed top 294 components, new dim = 2, correlation = 0.0682
# Removed top 295 components, new dim = 2, correlation = 0.0551
# Removed top 296 components, new dim = 2, correlation = 0.0647
# Removed top 297 components, new dim = 2, correlation = 0.0557
# Removed top 298 components, new dim = 2, correlation = 0.0498
#
# Best correlation: 0.2073

# %%
import pandas as pd
# Save the 2D embeddings with word labels to a CSV file
def save_embeddings_to_csv(words, embeddings, file_path):
    print(f"Saving 2D embeddings to {file_path}...")
    df = pd.DataFrame(embeddings, columns=['x', 'y'])
    df['word'] = words
    df.to_csv(file_path, index=False)
    print("2D embeddings saved successfully.")

# %%
# Get words and their high-dimensional embeddings
words = original_model.index_to_key  # List of words in vocabulary
file_path="FastText_TSVD_2d_word_embeddings.csv"
# Save the embeddings and words to a CSV file
save_embeddings_to_csv(words, optimized_embeddings, file_path)
# Out:
# Saving 2D embeddings to FastText_TSVD_2d_word_embeddings.csv...
# 2D embeddings saved successfully.
